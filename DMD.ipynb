# %%
# %reset -f

# %%
# This code will create a DMD Matrix based on the X and Y (snapshot) matrix

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.sparse.linalg import eigs, eigsh
from scipy.linalg import eig

# %%
# Read Input
def read_variables_to_globals(filename):
    with open(filename, 'r') as f:
        lines = [line.strip() for line in f.readlines()]

    for i in range(0, len(lines), 2):
        var_name = lines[i]
        raw_value = lines[i+1]

        try:
            value = int(raw_value)
        except ValueError:
            try:
                value = float(raw_value)
            except ValueError:
                value = raw_value

        globals()[var_name] = value  # Define variable in global scope

# %%
def DMD(ProjectName, NumSS, NumModes):
    # We need an A matrix, such that X = AY. where Y is a snapshot matrix defined as Y = X_{i+1}

    # A_tilde defined as operator that works in the column space of the snapshot matrix X.
    #   -> A_tilde = U^{T} * Y * V * Sigma^(-1)

    # Find Vt and Sigma of X (X has NumSS - 1 snaphots)
    corr_X = np.zeros((NumSS - 1, NumSS - 1))  # Initialize correlation matrix
    ModeSize = 0 # Intialize the size of each mode

    # Perform every dot product combo on the column snapshots in order to build the correlation matrix
    for i in range(NumSS-1):
        for j in range(i, NumSS-1):  # j starts at i
            snap_id_a = i + 1
            snap_id_b = j + 1

            snap_filename_a = ProjectName + "_SnapShot_"  + str(snap_id_a) + ".txt"
            snap_filename_b = ProjectName + "_SnapShot_"  + str(snap_id_b) + ".txt"

            snap_a = np.loadtxt(snap_filename_a)
            snap_b = np.loadtxt(snap_filename_b)

            if i == 0 and j == 0:
                ModeSize = len(snap_a)

            corr_X[i, j] = np.dot(snap_a, snap_b) 
            corr_X[j, i] = corr_X[i, j]       # fill symmetric entry

    eig_corr, tempModes = np.linalg.eigh(corr_X)
    print("Size of the eigenvalues")
    print(eig_corr.size)
    
    tempModes = tempModes[:, ::-1]  # Flip columns

    Vt_X = np.transpose(tempModes)
    S_X = np.sqrt(eig_corr)
    S_X = S_X[::-1]

    print("Vt_X")
    print(Vt_X)
    print("V_X")
    print(tempModes)

    print("S_X")
    print(S_X)

    # TODO: Maybe Using inv is a bad idea
    Sinv = np.diag(1/S_X)
    # print("Inverse of S")
    # print(Sinv)

    # Calculate U^{T} * Y in one loop (end result should be the size of (NumSS - 1) by (NumSS -1 ))

    UtY = np.zeros((NumSS-1, NumSS-1)) # Initialize UtY
    
    for k in range(NumSS-1): 
        mode_init = np.zeros(ModeSize)
        # Find each mode of X (columns of U)
        for i in range(NumSS-1):
            snapshot_id = i + 1
            snap_filename = ProjectName + "_SnapShot_"  + str(snapshot_id) + ".txt"
            snapshot = np.loadtxt(snap_filename)
            
            mode_init = mode_init + snapshot*Vt_X[k,i]*S_X[k]**(-1)

        # Use newly calculated mode to fill in the kth row of UtY 
        for i in range(NumSS-1):
            Y_ID = i + 2
            Ycol_filename = ProjectName + "_SnapShot_"  + str(Y_ID) + ".txt"
            Ycol = np.loadtxt(Ycol_filename)
            UtY[k,i] = np.dot(mode_init, Ycol)

    # print("UtY")
    # print(UtY)
    
    # Perform UtY * V * sigma^(-1)
    UtYV = UtY@tempModes
    A_tilde = np.linalg.solve(np.diag(S_X), UtYV.T).T
    # print(A_tilde)

    # Find Eigenvalues and eigenvectors of A_tilde to get the DMD modes and eigenvalues
    DMD_eig, DMD_modes_small = eig(A_tilde)
    DMD_eig_mag = np.abs(DMD_eig)
    print("Magnitude of DMD Eigenvalues")
    print(DMD_eig_mag)
    # DMD_modes_small = DMD_modes_small[:, ::-1] # Flip columns
    # DMD_eig = DMD_eig[::-1]

    print("DMD Eigenvalues")
    print(DMD_eig)

    # Find find the Mode Magnitude
    b = np.dot(np.matmul(np.linalg.inv(np.matmul(DMD_modes_small,np.diag(DMD_eig))), np.diag(S_X)), Vt_X[:, [0]])
    b = b.flatten()
    b_mag = np.abs(b)
    b_mag = b_mag.flatten()

    print('b:')
    print(b)
    print("Magnitudes for Modes:")
    print(b_mag)

    # Step 1: Get top-k indices of b (sorted by magnitude)
    top_k_indices = np.argsort(b_mag)[-NumModes:][::-1]

    # Step 2: Get top-k magnitudes
    top_k_magnitudes = b_mag[top_k_indices]

    # Step 3: Extract corresponding mode columns
    top_k_modes = DMD_modes_small[:, top_k_indices]

    # Print results
    print("Top-k indices:", top_k_indices)
    print("Top-k magnitudes:", top_k_magnitudes)
    print("Top mode:", top_k_modes[:,0])


    # Reinflate the modes into higher dimensional form
    DMD_modes = np.zeros((ModeSize, NumModes), dtype = complex)
    for k in range(NumModes): # Loop to reinflate specified number of modes 
        DMD_mode_init = np.zeros(ModeSize, dtype=complex)

        VSinvDMDsmall = tempModes @ np.diag(1/S_X) @ top_k_modes[:,k]
        # right_side = tempModes.T @ DMD_modes_small[:, k]
        # VSinvDMDsmall = np.linalg.solve(np.diag(S_X), right_side)
        
        for i in range(NumSS-1):
            snapshot_id_Y = i + 2
            snap_filename_Y = ProjectName + "_SnapShot_"  + str(snapshot_id_Y) + ".txt"
            snapshot_Y = np.loadtxt(snap_filename_Y)
            DMD_mode_init = DMD_mode_init + snapshot_Y*VSinvDMDsmall[i]

        DMD_modes[:, k] = DMD_mode_init

    print("Leading DMD Mode:")
    print(DMD_modes[:,0])
    
    return DMD_eig, DMD_modes, b

# %%
# Plot complex eigenvalues on a unit circle with B_k (use later)

def plot_eigs_on_unit_circle(eigvals, b_k, n=1, cmap='viridis'):
    """
    Plot complex eigenvalues on the complex plane with a unit circle.
    
    Parameters
    ----------
    eigvals : np.ndarray
        Complex eigenvalues (1D array).
    b_k : np.ndarray
        Mode amplitudes (same length as eigvals).
    n : int
        Exponent for lambda in |lambda^n * b_k| (default: 1).
    cmap : str
        Colormap for points (default: 'viridis').
    """

    # Compute color values
    color_values = np.abs((eigvals**n) * b_k)

    fig, ax = plt.subplots(figsize=(6,6))

    # Plot unit circle
    theta = np.linspace(0, 2*np.pi, 500)
    ax.plot(np.cos(theta), np.sin(theta), 'k', linewidth=2)

    # Scatter plot of eigenvalues
    sc = ax.scatter(eigvals.real, eigvals.imag, 
                    c=color_values, cmap=cmap, s=100, edgecolors='k')

    # Labels and formatting
    ax.set_xlabel(r"Re($\lambda_k$)")
    ax.set_ylabel(r"Im($\lambda_k$)")
    ax.set_aspect('equal', adjustable='box')

    # Colorbar
    cbar = plt.colorbar(sc, ax=ax)
    cbar.set_label(r"$|\lambda_k^n b_k|$")

    plt.show()

# %%
# Plot Eigenvalues on unit circle only without weighting
def plot_complex_on_unit_circle(complex_array):
    """
    Plot complex numbers on the unit circle.
    
    Parameters:
    - complex_array: NumPy array of complex numbers
    """
    # Ensure it's a NumPy array
    complex_array = np.asarray(complex_array, dtype=complex)
    
    # Unit circle points
    theta = np.linspace(0, 2 * np.pi, 500)
    unit_circle_x = np.cos(theta)
    unit_circle_y = np.sin(theta)

    # Extract real and imaginary parts
    real_parts = np.real(complex_array)
    imag_parts = np.imag(complex_array)

    # Plot
    plt.figure(figsize=(6, 6))
    plt.plot(unit_circle_x, unit_circle_y, 'k--', label="Unit Circle")  # dashed circle
    plt.scatter(real_parts, imag_parts, color='red', zorder=5, label="Complex Points")
    plt.axhline(0, color='gray', lw=0.8)
    plt.axvline(0, color='gray', lw=0.8)
    plt.gca().set_aspect('equal', adjustable='box')
    plt.xlabel('Real')
    plt.ylabel('Imaginary')
    plt.title('Complex Numbers on the Unit Circle')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# Plot the eigenvalues against amountof energy they each contain

# %%
# Plot temporal dynamics
def plot_dmd_temporal_modes(eigs, deltat, NumModes, num_time_steps=200):
    """
    Plots the temporal behavior of the first NumModes DMD eigenvalues.
    
    Parameters:
    - eigs: 1D numpy array of DMD eigenvalues (complex), length >= NumModes
    - deltat: time spacing between snapshots
    - NumModes: number of leading modes to plot
    - num_time_steps: number of points in the time array
    """
    t = np.linspace(0, (num_time_steps - 1) * deltat, num_time_steps)
    fig, axs = plt.subplots(NumModes, 1, figsize=(8, 2.5 * NumModes), sharex=True)

    if NumModes == 1:
        axs = [axs]  # wrap for consistency

    for i in range(NumModes):
        # Continuous-time eigenvalue
        omega_c = np.log(eigs[i]) / deltat
        sigma = omega_c.real      # growth/decay rate
        omega = omega_c.imag      # angular frequency (rad/s)

        # Real part of mode time evolution
        time_course = np.exp(sigma * t) * np.cos(omega * t)

        axs[i].plot(t, time_course, linewidth=2)
        axs[i].set_title(
            f"DMD Mode {i+1}: σ={sigma:.3f}, f={omega/(2*np.pi):.3f} Hz",
            fontsize=12
        )
        axs[i].set_ylabel("Amplitude")
        axs[i].grid(True)

    axs[-1].set_xlabel("Time")
    plt.tight_layout()
    plt.show()

# %%
# Print Modes
def save_modes(ProjectName, DMD_modes):
    """
    Saves each column of the DMD mode matrix into separate text files.

    Parameters:
    - ProjectName (str): Base name for output files
    - DMD_modes (numpy.ndarray): DMD mode matrix (shape: [n, NumModes])
    """

    num_cols = DMD_modes.shape[1]

    for DMDmode_col_id in range(1, num_cols + 1):
        # Create filename with mode index
        filename_out = f"{ProjectName}_dmdMode_{DMDmode_col_id}.txt"

        # Extract and reshape the column
        col_data = DMD_modes[:, DMDmode_col_id - 1].reshape(-1, 1)

        # Save to file
        np.savetxt(filename_out, col_data, fmt="%.6e")
        print(f"Saved: {filename_out}")

# %%
def main(ProjectName, NumSS, NumModes):
    DMD_eig, DMD_modes, b_k = DMD(ProjectName, NumSS, NumModes)
    return DMD_eig, DMD_modes, b_k

# %%
if __name__ == "__main__":
    # Read Variables
    inputs = read_variables_to_globals("input_DMD.txt")
    
    DMD_eig, DMD_modes, b_k = main(ProjectName, NumSS, NumModes)
    
    # Plot Eigenvalues on Unit Circle
    plot_complex_on_unit_circle(DMD_eig)

    # Plot Eigenvalues of DMD matrix (weighted with b magnitude)
    plot_eigs_on_unit_circle(DMD_eig, b_k, n=1, cmap='coolwarm')
          
    

    # Print the Modes to text files
    save_modes(ProjectName, DMD_modes)
# Out:
# Size of the eigenvalues
# 150
# Vt_X
# [[-0.04509049 -0.0669129  -0.08620171 ...  0.04854544  0.02753431
#    0.00499241]
#  [ 0.10645349  0.09477702  0.07873112 ...  0.10376129  0.11183253
#    0.11532911]
#  [ 0.01117338  0.05706028  0.09282162 ... -0.11528901 -0.108601
#   -0.08333167]
#  ...
#  [ 0.09547345  0.07261503  0.10430293 ...  0.18509075  0.03384947
#   -0.06326302]
#  [ 0.02905183  0.01188716  0.00509475 ... -0.0734265   0.04148569
#   -0.00146728]
#  [-0.07193494 -0.07621261 -0.08449231 ... -0.08629397 -0.08156799
#   -0.07534322]]
# V_X
# [[-0.04509049  0.10645349  0.01117338 ...  0.09547345  0.02905183
#   -0.07193494]
#  [-0.0669129   0.09477702  0.05706028 ...  0.07261503  0.01188716
#   -0.07621261]
#  [-0.08620171  0.07873112  0.09282162 ...  0.10430293  0.00509475
#   -0.08449231]
#  ...
#  [ 0.04854544  0.10376129 -0.11528901 ...  0.18509075 -0.0734265
#   -0.08629397]
#  [ 0.02753431  0.11183253 -0.108601   ...  0.03384947  0.04148569
#   -0.08156799]
#  [ 0.00499241  0.11532911 -0.08333167 ... -0.06326302 -0.00146728
#   -0.07534322]]
# S_X
# [1.29903664e+03 1.27035036e+03 4.66196081e+02 4.61428134e+02
#  3.64874674e+02 3.56346775e+02 1.45585473e+02 1.44558780e+02
#  7.70413546e+01 7.64283125e+01 3.73713812e+01 3.71391293e+01
#  2.18084639e+01 2.16097611e+01 1.23734933e+01 1.23258469e+01
#  6.90261924e+00 6.84464809e+00 3.59441019e+00 3.57285059e+00
#  1.91331594e+00 1.90611142e+00 9.84534344e-01 9.80277090e-01
#  4.97683934e-01 4.96606159e-01 2.44440096e-01 2.40711093e-01
#  1.22591165e-01 1.08919822e-01 5.44516577e-02 5.27917825e-02
#  2.50499221e-02 2.47301079e-02 1.14389781e-02 1.13221850e-02
#  5.19829858e-03 5.15781004e-03 2.37719866e-03 2.36167379e-03
#  1.16093108e-03 1.14766900e-03 7.69714355e-04 7.63710219e-04
#  7.37965113e-04 7.25121936e-04 7.14332097e-04 7.00673245e-04
#  6.96099736e-04 6.87982025e-04 6.83057280e-04 6.79378250e-04
#  6.74298053e-04 6.71738486e-04 6.58373408e-04 6.55808144e-04
#  6.52613012e-04 6.46625756e-04 6.39436447e-04 6.35782986e-04
#  6.27938758e-04 6.22161621e-04 6.20920841e-04 6.14922919e-04
#  6.12072763e-04 6.08446512e-04 5.99701438e-04 5.98162332e-04
#  5.93705861e-04 5.91872836e-04 5.86809041e-04 5.82645977e-04
#  5.77427767e-04 5.77071521e-04 5.72647879e-04 5.69125386e-04
#  5.60070948e-04 5.58192435e-04 5.54337871e-04 5.53052279e-04
#  5.44739749e-04 5.44472940e-04 5.33060666e-04 5.31078493e-04
#  5.27329351e-04 5.27051351e-04 5.23885956e-04 5.22655641e-04
#  5.22512079e-04 5.19183230e-04 5.15198041e-04 5.09658730e-04
#  5.06925499e-04 5.05154427e-04 4.99667379e-04 4.97340897e-04
#  4.91903792e-04 4.89755127e-04 4.88172679e-04 4.85859634e-04
#  4.83351358e-04 4.78732642e-04 4.74984070e-04 4.72738969e-04
#  4.72040204e-04 4.68885807e-04 4.67440075e-04 4.63318970e-04
#  4.60254693e-04 4.59143528e-04 4.56433729e-04 4.49328970e-04
#  4.46950363e-04 4.44849542e-04 4.41536187e-04 4.40944760e-04
#  4.40555442e-04 4.37546124e-04 4.37333389e-04 4.31936205e-04
#  4.30516468e-04 4.26439499e-04 4.25832932e-04 4.24748698e-04
#  4.21377921e-04 4.19888219e-04 4.17751992e-04 4.15576985e-04
#  4.14896446e-04 4.08775558e-04 4.08160227e-04 4.08025111e-04
#  4.05831907e-04 4.04381596e-04 4.01862416e-04 4.00104876e-04
#  3.97940798e-04 3.96630429e-04 3.94428497e-04 3.94229236e-04
#  3.92747167e-04 3.89922619e-04 3.88112115e-04 3.87628897e-04
#  3.81980079e-04 3.81560214e-04 3.80908279e-04 3.75564241e-04
#  3.74367126e-04 2.09743445e-04]
# Magnitude of DMD Eigenvalues
# [1.00007637 1.00007637 0.99872002 0.99872002 0.98968138 0.98968138
#  0.99432426 0.99432426 0.99930006 0.99930006 0.98624961 0.98624961
#  0.99042953 0.99042953 1.00010245 1.00010245 0.98830629 0.98830629
#  0.97519587 0.97519587 1.00007693 1.00007693 0.99556649 0.99556649
#  0.96323841 0.96323841 0.99313834 0.99313834 0.99094152 0.99094152
#  0.98277869 0.98277869 0.98813254 0.98813254 1.00007849 1.00007849
#  0.98037041 0.98037041 0.9856595  0.9856595  0.98777808 0.98777808
#  0.99103425 0.99103425 0.95559257 0.95559257 0.98658275 0.98658275
#  1.00005369 1.00005369 0.98429632 0.98429632 1.00003608 1.00003608
#  0.99395117 0.99395117 0.99585767 0.99585767 0.96209082 0.96209082
#  0.98928204 0.98928204 1.00003447 1.00003447 0.98980309 0.98980309
#  0.990195   0.990195   0.98283547 0.98283547 0.99041336 0.99041336
#  0.99217298 0.99217298 1.00001902 1.00001902 1.00000548 1.00000548
#  0.99983783 0.99983783 1.00000678 1.00000678 0.99138311 0.99138311
#  0.99083025 0.99083025 0.98859723 0.98859723 1.00001838 1.00001838
#  0.99908057 0.99908057 0.97155608 0.97155608 1.00000962 1.00000962
#  0.98472602 0.98472602 0.96079414 0.96079414 0.9899492  0.9899492
#  0.99987801 0.99987801 0.99763672 0.99763672 0.99469356 0.99469356
#  0.9933415  0.9933415  0.99998643 0.99998643 0.9912152  0.9912152
#  0.98388537 0.98388537 0.99488121 0.99488121 0.99990457 0.99990457
#  0.99998784 0.99998784 0.99993158 0.99993158 0.99994622 0.99994622
#  0.99130988 0.99130988 0.98681842 0.98681842 0.98687661 0.98687661
#  0.95316534 0.95316534 0.96054491 0.96054491 0.99238187 0.99238187
#  0.95366018 0.95366018 0.92059704 0.92059704 0.98383057 0.98383057
#  0.94024811 0.94024811 0.94255221 0.94255221 0.90953691 0.90953691]
# DMD Eigenvalues
# [ 0.97854278+0.20641407j  0.97854278-0.20641407j  0.99813179+0.03427266j
#   0.99813179-0.03427266j  0.98700889+0.07268205j  0.98700889-0.07268205j
#   0.98801216+0.11186023j  0.98801216-0.11186023j  0.98722748+0.1548629j
#   0.98722748-0.1548629j   0.95978581+0.226935j    0.95978581-0.226935j
#   0.9527807 +0.27048032j  0.9527807 -0.27048032j  0.91492058+0.40388765j
#   0.91492058-0.40388765j  0.93431671+0.32218256j  0.93431671-0.32218256j
#   0.910594  +0.34903517j  0.910594  -0.34903517j  0.81184651+0.58400266j
#   0.81184651-0.58400266j  0.88212462+0.46152876j  0.88212462-0.46152876j
#   0.88014543+0.39137227j  0.88014543-0.39137227j  0.85840386+0.49946629j
#   0.85840386-0.49946629j  0.83450728+0.53438065j  0.83450728-0.53438065j
#   0.78304529+0.59388048j  0.78304529-0.59388048j  0.75693413+0.63518237j
#   0.75693413-0.63518237j  0.67387415+0.73895238j  0.67387415-0.73895238j
#   0.7210783 +0.66420796j  0.7210783 -0.66420796j  0.70207742+0.69181786j
#   0.70207742-0.69181786j  0.61819149+0.7704186j   0.61819149-0.7704186j
#   0.58475303+0.80013298j  0.58475303-0.80013298j  0.62376532+0.72392955j
#   0.62376532-0.72392955j  0.54614304+0.82162844j  0.54614304-0.82162844j
#   0.50685993+0.86209071j  0.50685993-0.86209071j  0.46559644+0.86721347j
#   0.46559644-0.86721347j  0.31806585+0.94810668j  0.31806585-0.94810668j
#   0.41007752+0.90541447j  0.41007752-0.90541447j  0.36912068+0.92492292j
#   0.36912068-0.92492292j  0.43566534+0.85779628j  0.43566534-0.85779628j
#   0.27727985+0.94962879j  0.27727985-0.94962879j  0.11555544+0.99333574j
#   0.11555544-0.99333574j  0.23535065+0.96141574j  0.23535065-0.96141574j
#   0.17562447+0.97449587j  0.17562447-0.97449587j  0.07936557+0.97962578j
#   0.07936557-0.97962578j  0.0194883 +0.99022161j  0.0194883 -0.99022161j
#  -0.0386441 +0.99142012j -0.0386441 -0.99142012j -0.0918956 +0.99578774j
#  -0.0918956 -0.99578774j -0.65605384+0.75472136j -0.65605384-0.75472136j
#  -0.69111425+0.72252113j -0.69111425-0.72252113j -0.48623049+0.87383836j
#  -0.48623049-0.87383836j -0.73033962+0.67040622j -0.73033962-0.67040622j
#  -0.61285024+0.77856225j -0.61285024-0.77856225j -0.57759688+0.80231311j
#  -0.57759688-0.80231311j -0.79769887+0.60308645j -0.79769887-0.60308645j
#  -0.5274438 +0.84850752j -0.5274438 -0.84850752j -0.70220915+0.67143392j
#  -0.70220915-0.67143392j -0.29540813+0.95538122j -0.29540813-0.95538122j
#  -0.76473871+0.62037089j -0.76473871-0.62037089j -0.52028028+0.80773374j
#  -0.52028028-0.80773374j -0.44213431+0.88572946j -0.44213431-0.88572946j
#  -0.82543679+0.56427844j -0.82543679-0.56427844j -0.34194652+0.93720414j
#  -0.34194652-0.93720414j -0.13744934+0.98515124j -0.13744934-0.98515124j
#  -0.84908126+0.51554665j -0.84908126-0.51554665j -0.90493747+0.42551267j
#  -0.90493747-0.42551267j -0.87106101+0.47303308j -0.87106101-0.47303308j
#  -0.39094653+0.90287941j -0.39094653-0.90287941j -0.24078851+0.96530281j
#  -0.24078851-0.96530281j -0.92412884+0.38183116j -0.92412884-0.38183116j
#  -0.97327029+0.22960974j -0.97327029-0.22960974j -0.98305657+0.18292878j
#  -0.98305657-0.18292878j -0.99966191+0.02384327j -0.99966191-0.02384327j
#  -0.93709513+0.3233388j  -0.93709513-0.3233388j  -0.94810419+0.27369515j
#  -0.94810419-0.27369515j -0.19113193+0.96819111j -0.19113193-0.96819111j
#  -0.35665576+0.88392355j -0.35665576-0.88392355j  0.01663094+0.96040092j
#   0.01663094-0.96040092j -0.98456524+0.12431036j -0.98456524-0.12431036j
#   0.18556273+0.93543263j  0.18556273-0.93543263j -0.80282114+0.45052983j
#  -0.80282114-0.45052983j -0.98033977+0.08280415j -0.98033977-0.08280415j
#  -0.89086293+0.30071538j -0.89086293-0.30071538j -0.18103625+0.92500299j
#  -0.18103625-0.92500299j -0.90629369+0.07674071j -0.90629369-0.07674071j]
# b:
# [-2.13275768e+01+1.01921127e+02j -2.13275768e+01-1.01921127e+02j
#  -1.55561712e-01-4.47658524e-02j -1.55561712e-01+4.47658522e-02j
#  -2.43848361e-01-1.44906299e-01j -2.43848361e-01+1.44906300e-01j
#  -1.05322920e-01-1.67285298e-01j -1.05322920e-01+1.67285298e-01j
#  -1.20127068e-01-1.06209465e-01j -1.20127067e-01+1.06209465e-01j
#   2.97418382e-02+1.08319143e+00j  2.97418382e-02-1.08319143e+00j
#  -9.35610110e-02+1.72043906e-01j -9.35610110e-02-1.72043906e-01j
#   1.17343732e+01+3.55194480e+01j  1.17343732e+01-3.55194480e+01j
#  -1.38960457e-01-1.32149162e-01j -1.38960457e-01+1.32149162e-01j
#   6.95493164e-01+1.68068271e-01j  6.95493164e-01-1.68068271e-01j
#  -1.84246248e+01+2.27688507e+01j -1.84246248e+01-2.27688507e+01j
#   5.14590072e-02-2.94530316e-02j  5.14590072e-02+2.94530316e-02j
#  -1.24835337e+00+8.40856972e-01j -1.24835337e+00-8.40856972e-01j
#  -6.07532725e-02-9.69658114e-03j -6.07532725e-02+9.69658113e-03j
#   9.67170851e-02+3.07786138e-03j  9.67170851e-02-3.07786137e-03j
#   1.35349612e-01-3.72602213e-01j  1.35349612e-01+3.72602213e-01j
#   4.17991556e-02-8.08647645e-02j  4.17991556e-02+8.08647645e-02j
#  -5.10601423e+00-1.05919877e+01j -5.10601423e+00+1.05919877e+01j
#  -1.35957761e-01-6.84721792e-02j -1.35957761e-01+6.84721792e-02j
#   9.88719519e-02+5.64290233e-02j  9.88719519e-02-5.64290233e-02j
#   6.25664453e-02-1.62988284e-02j  6.25664453e-02+1.62988284e-02j
#   2.04334293e-02-2.08770020e-02j  2.04334293e-02+2.08770020e-02j
#  -3.92148436e-01-3.18258204e-01j -3.92148436e-01+3.18258204e-01j
#   3.61710969e-02+1.65025972e-03j  3.61710969e-02-1.65025972e-03j
#  -2.18320305e+00+5.86304702e+00j -2.18320305e+00-5.86304702e+00j
#  -7.20038381e-02-5.13818957e-02j -7.20038381e-02+5.13818957e-02j
#   3.01526824e+00+3.84678566e-01j  3.01526824e+00-3.84678566e-01j
#  -7.42947859e-03+9.19698877e-03j -7.42947860e-03-9.19698877e-03j
#   1.34066063e-03+8.00408172e-03j  1.34066063e-03-8.00408172e-03j
#   1.24223148e-01-1.39459271e-01j  1.24223148e-01+1.39459271e-01j
#   1.38516544e-02+1.29858243e-02j  1.38516544e-02-1.29858243e-02j
#  -1.23128800e-01+1.76935233e+00j -1.23128800e-01-1.76935233e+00j
#   1.13554012e-02+6.06145106e-03j  1.13554012e-02-6.06145106e-03j
#   4.65239469e-03+1.05547890e-02j  4.65239469e-03-1.05547890e-02j
#   1.34024728e-02+2.00605468e-02j  1.34024728e-02-2.00605468e-02j
#   8.92117430e-05+1.08934214e-02j  8.92117429e-05-1.08934214e-02j
#   5.49972983e-03-3.35248124e-04j  5.49972983e-03+3.35248124e-04j
#  -1.00667312e+00-4.98093243e-02j -1.00667312e+00+4.98093243e-02j
#  -1.54108461e-01-2.57975223e-02j -1.54108461e-01+2.57975223e-02j
#   1.20592673e-03-9.18354964e-04j  1.20592673e-03+9.18354964e-04j
#  -2.92878014e-01+4.65334377e-03j -2.92878014e-01-4.65334377e-03j
#  -8.56242280e-04+4.03410118e-03j -8.56242280e-04-4.03410118e-03j
#  -4.42573169e-04-3.02827886e-03j -4.42573169e-04+3.02827886e-03j
#  -4.65479353e-04+4.25359160e-03j -4.65479353e-04-4.25359160e-03j
#  -2.14914068e-02+7.73893981e-02j -2.14914068e-02-7.73893981e-02j
#   1.35804672e-03-2.26015658e-03j  1.35804672e-03+2.26015658e-03j
#   1.61506780e-02-2.17994726e-03j  1.61506780e-02+2.17994726e-03j
#   9.32268021e-02-5.53721362e-01j  9.32268021e-02+5.53721362e-01j
#   4.57398804e-03-1.14762372e-04j  4.57398804e-03+1.14762371e-04j
#   1.62236332e-02+2.49507101e-02j  1.62236332e-02-2.49507101e-02j
#   6.94106541e-04+4.73866856e-03j  6.94106541e-04-4.73866856e-03j
#   1.42282748e-03-4.85322943e-04j  1.42282748e-03+4.85322943e-04j
#  -1.79840106e-03+2.37499929e-03j -1.79840106e-03-2.37499929e-03j
#  -9.29199243e-04+4.45648598e-03j -9.29199243e-04-4.45648598e-03j
#  -1.72128865e-03-1.18717645e-03j -1.72128865e-03+1.18717645e-03j
#   7.56150317e-03+4.01671676e-02j  7.56150317e-03-4.01671676e-02j
#  -2.17686319e-03+1.27215429e-03j -2.17686319e-03-1.27215429e-03j
#  -9.04839002e-03+4.22848145e-03j -9.04839002e-03-4.22848145e-03j
#  -2.98182228e-03+2.01676371e-03j -2.98182228e-03-2.01676371e-03j
#  -2.16978815e-03+9.27615800e-04j -2.16978815e-03-9.27615800e-04j
#  -1.88595895e-02-6.67019414e-03j -1.88595895e-02+6.67019414e-03j
#  -8.18716513e-04-4.54034288e-03j -8.18716513e-04+4.54034288e-03j
#   9.43154587e-03+2.19201574e-03j  9.43154587e-03-2.19201574e-03j
#  -2.82213664e-03+3.21824095e-04j -2.82213664e-03-3.21824095e-04j
#  -2.59372248e-04-3.92687396e-03j -2.59372248e-04+3.92687396e-03j
#  -6.85756456e-03-6.48786053e-03j -6.85756456e-03+6.48786053e-03j
#   4.16363717e-02+3.67964228e-02j  4.16363717e-02-3.67964228e-02j
#   1.60469083e-02+7.08306325e-02j  1.60469083e-02-7.08306325e-02j
#   2.09025440e-03+3.43826445e-04j  2.09025440e-03-3.43826445e-04j
#   5.11441803e-02+8.91076639e-02j  5.11441803e-02-8.91076639e-02j
#   5.90514497e-02-1.50996550e-02j  5.90514497e-02+1.50996550e-02j
#  -4.52101288e-03+8.19293811e-04j -4.52101288e-03-8.19293811e-04j
#   4.63694057e-02-6.74252449e-03j  4.63694057e-02+6.74252449e-03j
#   5.34154524e-02+6.32344438e-02j  5.34154524e-02-6.32344438e-02j
#  -8.72207571e-02+3.53950241e-02j -8.72207571e-02-3.53950241e-02j]
# Magnitudes for Modes:
# [1.04128678e+02 1.04128678e+02 1.61874729e-01 1.61874729e-01
#  2.83654470e-01 2.83654471e-01 1.97679762e-01 1.97679762e-01
#  1.60346384e-01 1.60346384e-01 1.08359968e+00 1.08359968e+00
#  1.95838628e-01 1.95838628e-01 3.74075754e+01 3.74075754e+01
#  1.91763942e-01 1.91763942e-01 7.15512183e-01 7.15512183e-01
#  2.92897142e+01 2.92897142e+01 5.92917405e-02 5.92917405e-02
#  1.50513341e+00 1.50513341e+00 6.15222221e-02 6.15222221e-02
#  9.67660466e-02 9.67660466e-02 3.96423923e-01 3.96423923e-01
#  9.10290039e-02 9.10290039e-02 1.17584686e+01 1.17584686e+01
#  1.52226647e-01 1.52226647e-01 1.13841546e-01 1.13841546e-01
#  6.46545581e-02 6.46545581e-02 2.92125700e-02 2.92125700e-02
#  5.05043246e-01 5.05043246e-01 3.62087228e-02 3.62087228e-02
#  6.25633247e+00 6.25633247e+00 8.84570625e-02 8.84570625e-02
#  3.03970725e+00 3.03970725e+00 1.18229334e-02 1.18229334e-02
#  8.11558348e-03 8.11558348e-03 1.86762627e-01 1.86762627e-01
#  1.89868366e-02 1.89868366e-02 1.77363141e+00 1.77363141e+00
#  1.28719200e-02 1.28719200e-02 1.15346586e-02 1.15346586e-02
#  2.41257501e-02 2.41257501e-02 1.08937867e-02 1.08937867e-02
#  5.50993825e-03 5.50993825e-03 1.00790463e+00 1.00790463e+00
#  1.56252776e-01 1.56252776e-01 1.51579521e-03 1.51579521e-03
#  2.92914978e-01 2.92914978e-01 4.12396935e-03 4.12396935e-03
#  3.06044831e-03 3.06044831e-03 4.27898499e-03 4.27898499e-03
#  8.03181144e-02 8.03181144e-02 2.63677808e-03 2.63677808e-03
#  1.62971338e-02 1.62971338e-02 5.61514545e-01 5.61514545e-01
#  4.57542752e-03 4.57542752e-03 2.97614551e-02 2.97614551e-02
#  4.78923414e-03 4.78923414e-03 1.50332179e-03 1.50332179e-03
#  2.97907167e-03 2.97907167e-03 4.55232671e-03 4.55232671e-03
#  2.09098602e-03 2.09098602e-03 4.08727009e-02 4.08727009e-02
#  2.52133097e-03 2.52133097e-03 9.98766325e-03 9.98766325e-03
#  3.59980554e-03 3.59980554e-03 2.35975670e-03 2.35975670e-03
#  2.00043897e-02 2.00043897e-02 4.61356806e-03 4.61356806e-03
#  9.68292262e-03 9.68292262e-03 2.84042707e-03 2.84042707e-03
#  3.93543048e-03 3.93543048e-03 9.44026090e-03 9.44026090e-03
#  5.55658545e-02 5.55658545e-02 7.26256274e-02 7.26256274e-02
#  2.11834371e-03 2.11834371e-03 1.02741924e-01 1.02741924e-01
#  6.09514011e-02 6.09514011e-02 4.59464904e-03 4.59464904e-03
#  4.68570531e-02 4.68570531e-02 8.27756331e-02 8.27756331e-02
#  9.41289976e-02 9.41289976e-02]
# Top-k indices: [ 0  1 15 14 21 20 34 35 49 48]
# Top-k magnitudes: [104.12867809 104.12867809  37.40757543  37.40757543  29.28971423
#   29.28971423  11.75846863  11.75846863   6.25633247   6.25633247]
# Top mode: [ 7.12363924e-01+0.00000000e+00j -1.56045675e-03-7.01770832e-01j
#   2.16970102e-04+1.39593193e-03j  3.15107281e-04+4.06581841e-03j
#  -2.71842796e-03-2.78723015e-04j  3.95763727e-03+3.01199010e-03j
#   1.15777319e-04+5.88376010e-04j  1.48520777e-04+1.04725353e-03j
#  -3.28704603e-07+2.01465695e-04j -4.23294895e-05-6.26453359e-04j
#  -7.41522591e-06+1.32123333e-05j -5.01403076e-05-3.24746877e-04j
#  -8.80289551e-06-4.21576039e-06j -2.69096928e-05-1.88822377e-04j
#  -4.95029987e-06-7.72954779e-06j  1.67319703e-05+1.07265343e-04j
#   1.92470046e-06-1.43876509e-06j -1.00510992e-05-6.03092820e-05j
#  -2.13897017e-06-5.15085356e-06j -4.96895056e-06-3.12526466e-05j
#   7.71752571e-07+1.49675922e-07j  2.85971873e-06+1.69318971e-05j
#   3.07062411e-07-5.98968744e-07j  1.53337259e-06+8.62309361e-06j
#   5.25631193e-07+1.78579477e-06j  6.24127299e-07+3.96367753e-06j
#   3.98932994e-07+2.08790948e-06j -8.41185986e-08+1.61299838e-07j
#  -1.77219275e-07-9.27505858e-07j  7.51912853e-08+6.90335276e-08j
#  -4.40830449e-08-6.29328603e-08j -7.59139026e-08-3.88464997e-07j
#  -1.31098358e-08+7.29072890e-09j -4.06819671e-08-1.85088926e-07j
#  -7.56860131e-09-6.56484187e-09j -1.80983667e-08-8.31806314e-08j
#   3.81654364e-09+2.96155736e-09j -9.90950347e-09-3.64811098e-08j
#  -2.81290828e-09-6.46865196e-09j  6.61007699e-09+1.58218383e-08j
#  -8.74690873e-09+1.10648683e-08j -1.35449027e-09+1.45687858e-10j
#  -1.07006833e-08+1.69618005e-08j -2.05267846e-08+3.41027462e-08j
#  -3.97547798e-09-2.78087831e-08j -1.61169744e-09+3.35350645e-08j
#   1.92206167e-08+5.47317801e-10j -4.23574459e-08-1.72710155e-08j
#  -3.37847715e-08-2.14709345e-08j -2.43071200e-08+2.84987801e-08j
#   4.54277716e-09-2.75801652e-09j  1.25190189e-08-3.49218660e-08j
#   5.42036861e-08+1.27352435e-09j -2.45720897e-08-1.50840768e-08j
#  -1.53958160e-08+2.51441162e-08j -8.22137083e-10+3.17162174e-08j
#  -3.14166215e-08-6.57553186e-09j  5.55503395e-08+4.41937735e-09j
#   5.54911278e-08-2.94797745e-10j -4.05936486e-08+3.49067228e-08j
#  -9.00247393e-11+7.78960165e-09j  1.98205100e-08-6.94114390e-09j
#  -8.57758323e-09+2.38180569e-08j -2.43574377e-08-3.04282521e-08j
#  -2.77572451e-09+3.18896479e-09j  3.78207142e-08+2.93678262e-08j
#  -4.28123146e-09-3.19946150e-08j -1.91233436e-08+2.98253956e-08j
#   3.84858893e-09+1.21196360e-08j  2.05516246e-08-3.41360464e-08j
#   5.95083995e-10-2.28345978e-08j  2.44149645e-08-7.14272947e-09j
#   8.08002409e-09-3.18594558e-08j -3.07113339e-08+5.28259017e-08j
#  -2.08943593e-08+2.26878202e-08j -5.87709494e-09-3.91722897e-08j
#  -2.67511152e-08+3.43832794e-09j  1.92938285e-08-2.02730788e-08j
#  -4.86407632e-08-2.65707234e-08j  1.99875700e-08+7.36979777e-09j
#   3.68680327e-09-1.09480659e-08j -2.73647120e-09+3.19429282e-08j
#   1.34528051e-08+4.68490808e-08j  1.50679056e-09+7.27389788e-09j
#  -9.70164501e-09-4.32893275e-09j  1.90141838e-08+1.88098917e-08j
#  -1.02277949e-08+2.45200439e-08j  2.83496540e-08+2.03498724e-08j
#   3.99860016e-08-1.99594642e-09j  5.15236500e-09+1.36469323e-08j
#   4.53946787e-08-1.47464211e-08j  4.64358506e-08-8.85760509e-09j
#   1.58979267e-08-3.67109649e-08j -1.30129398e-08-2.02533408e-08j
#   6.49326271e-09-9.31217101e-09j  9.42847002e-09+4.41857400e-08j
#  -1.75438295e-08+8.97822251e-09j -2.27093155e-08+5.52612647e-09j
#   2.63406470e-08-3.18899663e-08j -2.73114960e-08-1.47461325e-08j
#  -1.27780084e-08-1.68538984e-08j -1.04054638e-08-2.35247043e-08j
#   4.26859562e-09+7.66497539e-09j  3.00766421e-08+3.92114215e-09j
#   3.54965794e-09-1.52257525e-08j  6.62319270e-10-8.70877728e-09j
#  -3.25431707e-08+6.97102970e-09j  2.80425057e-08-2.08490455e-08j
#   4.63783123e-11-5.00316331e-08j -1.97898294e-09+3.33877590e-08j
#   1.17111343e-08+2.98641687e-08j  7.11407927e-09-4.63263584e-09j
#  -4.43939079e-08-2.37773622e-08j  2.71278119e-08-1.29564470e-08j
#   7.80180090e-09+3.64470621e-08j -2.60226112e-08-1.73839878e-08j
#  -1.98675220e-08+1.77641451e-08j  7.45655467e-09-1.58621653e-08j
#   2.70704013e-08+1.85490472e-08j  8.26913995e-09+8.70863908e-09j
#   1.06276473e-08-1.67548221e-08j -1.67247023e-09+7.31460318e-09j
#  -5.36667606e-09+7.86835352e-09j  1.71635974e-08+3.27161249e-08j
#  -9.89725807e-09-2.63278004e-08j  1.51694602e-08+1.01944368e-08j
#  -4.09977588e-08+1.59641650e-08j  4.21571513e-09-6.58287541e-09j
#  -1.18531440e-08+2.47071951e-08j  2.81739375e-09-1.34853960e-09j
#   6.68932259e-09+6.98977042e-09j -2.00645786e-08+6.20963632e-09j
#   4.75598382e-09+1.90233706e-08j  1.54290318e-08-3.18824962e-08j
#   1.03037840e-08+1.70736367e-08j -2.88683979e-08-1.08012301e-09j
#  -5.49976836e-09+3.07403496e-09j  1.54161531e-08-1.16023183e-08j
#   3.53887152e-08+6.55597530e-10j -1.29547037e-08+8.91414656e-09j
#  -1.46290829e-08-1.99334927e-08j  3.24976772e-09+1.37118409e-08j
#  -6.39581712e-09-1.88884118e-08j  1.34903602e-08+2.55860397e-08j
#   3.24207766e-08+1.23322063e-08j -8.49580601e-09-1.46698310e-08j
#  -3.86315766e-09+1.90728633e-09j  8.95225014e-09+2.80202136e-09j
#  -1.00870372e-08+3.83452130e-09j -6.60491884e-08-2.40068592e-08j]
# Leading DMD Mode:
# [ 3.58017357e-18+2.70012842e-17j  3.98141269e-18+2.77074429e-17j
#   4.28145631e-18+2.83181172e-17j ... -4.85658232e-04+3.11659064e-04j
#  -4.62049563e-04+3.38903797e-04j -4.38782976e-04+3.63415344e-04j]
# Saved: Vortex_Avg_dmdMode_1.txt
# Saved: Vortex_Avg_dmdMode_2.txt
# Saved: Vortex_Avg_dmdMode_3.txt
# Saved: Vortex_Avg_dmdMode_4.txt
# Saved: Vortex_Avg_dmdMode_5.txt
# Saved: Vortex_Avg_dmdMode_6.txt
# Saved: Vortex_Avg_dmdMode_7.txt
# Saved: Vortex_Avg_dmdMode_8.txt
# Saved: Vortex_Avg_dmdMode_9.txt
# Saved: Vortex_Avg_dmdMode_10.txt
